# %%
# %matplotlib notebook

# %%
import numpy as np
import time
import warnings
from matplotlib import pyplot as plt
from dweepy.streaming import listen_for_dweets_from

# %%
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
plt.ion()
ydata = [0] * 50

# %%
ax1=plt.axes() 
 
# make plot
line, = plt.plot(ydata)
plt.ylim([0,100]) # set the y-range to 10 to 100
# Out:
# <img src="data:image/png;base64,...">
# (0, 100)

# %%
ymin = 0
ymax = 100
plt.ylim([ymin,ymax])
fig = plt.figure(1)

# %%
for d in listen_for_dweets_from("RRRioXYZ", 1000000):
    print d['content']['valll']
    ydata.append(int(d['content']['valll'])) 
    del ydata[0]
    line.set_xdata(np.arange(len(ydata)))
    line.set_ydata(ydata)  # update the data
#    plt.show() # update the plot
#    fig.canvas.draw()
#    plt.pause(0.001)
#    time.sleep(1)

    fig.show()
    fig.canvas.draw()

# %%
x = 5
print x
